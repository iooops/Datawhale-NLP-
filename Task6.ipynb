# %%
# https://github.com/datawhalechina/team-learning-nlp/blob/master/NewsTextClassification/Task6%20%E5%9F%BA%E4%BA%8E%E6%B7%B1%E5%BA%A6%E5%AD%A6%E4%B9%A0%E7%9A%84%E6%96%87%E6%9C%AC%E5%88%86%E7%B1%BB3.md
# https://tianchi.aliyun.com/notebook-ai/detail?spm=5176.12586969.1002.27.6406111aIKCSLV&postId=118260

# 强烈推荐熟读下面这两篇博客文章，图文并茂，讲得非常好，很适合入门。
# (https://jalammar.github.io/illustrated-transformer/) 
# (https://jalammar.github.io/visualizing-neural-machine-translation-mechanics-of-seq2seq-models-with-attention/)

# Bert的原始论文和代码：
# https://github.com/google-research/bert
# https://arxiv.org/pdf/1810.04805.pdf

# Tensorflow的Trnasformer官方教程，下一篇就是Bert的示例：
# https://www.tensorflow.org/tutorials/text/transformer

# %%
'''
Attention: 
以机器翻译为例。
先由RNN从encoder到decoder（seq2seq model）。
Attention的引入可以使得模型集中于输入的相关词。
| Attention allows the model to focus on the relevant parts of the input sequence as needed.
它与原先的模型的差异性在于：1、它把所有的hidden states传入decoder里 2、通过hidden state给decoder统计分数。

计算self-attention：

Q - queries,
K - keys,
V - values,
Z - sum of the weighted value vectors

'''

# %% [markdown]
# ![image.png](attachment:image.png)
#
# self-attention

# %%
'''
Transformer: 
基本结构如下图所示。先通过positional encoding进入encoders，然后再到decoders，经过linear layer和softmax layer进行输出。
positional encoding + embeddings = embedding with time signal
'''

# %% [markdown]
# ![image.png](attachment:image.png)
#
# transformer

# %%
'''
最后算出概率分布
'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 本章作业
# 完成Bert Pretrain和Finetune的过程
# 阅读Bert官方文档，找到相关参数进行调参
